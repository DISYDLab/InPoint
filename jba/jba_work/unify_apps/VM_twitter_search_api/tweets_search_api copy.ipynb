# %% [markdown]
# # Get Tweets
#
# This script extracts all the tweets with hashtag #covid-19 related to the day before today (yesterday) and saves them into a .csv file.
# We use the `tweepy` library, which can be installed with the command `pip install tweepy`.
#
# Firstly, we import the configuration file, called `config.py`, which is located in the same directory of this script.

# %%
from config import *
import tweepy
import datetime

import sys
import logging

logger = logging.getLogger('tweets_search')

# %%
import pandas as pd
# import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
print(f"logger.root.level = {logger.root.level}, logger.root.name = {logger.root.name}")
print(f"logger.name = {logger.name}")
# Out:
# logger.root.level = 20, logger.root.name = root
# logger.name = tweets_search

# %%
format = "%(asctime)s - %(levelname)s - %(message)s"
# logging.basicConfig(format=format, stream=sys.stdout, level = logging.DEBUG)
logging.basicConfig(format=format, stream=sys.stdout, level = logging.INFO)

# %%
print(logger.root.level)
# Out:
# 10

# %%
logger.root.level = 20

# %%
print(logger.root.level)
# Out:
# 20

# %% [markdown]
# We setup the connection to our Twitter App by using the `OAuthHandler()` class and its `access_token()` function. Then we call the Twitter API through the `API()` function.

# %%
auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify = True)

# %%
api.me()
# Out:
# 2021-06-20 22:48:36,158 - DEBUG - PARAMS: {'screen_name': b'vasiange'}
# 2021-06-20 22:48:36,162 - DEBUG - Signing request <PreparedRequest [GET]> using client <Client client_key=pw0ihLFxH3nwDrd4HBd7pqUrc, client_secret=****, resource_owner_key=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# 2021-06-20 22:48:36,165 - DEBUG - Including body in call to sign: False
# 2021-06-20 22:48:36,176 - DEBUG - Collected params: [('screen_name', 'vasiange'), ('oauth_nonce', '174152913811685627841624218516'), ('oauth_timestamp', '1624218516'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'pw0ihLFxH3nwDrd4HBd7pqUrc'), ('oauth_token', '1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz')]
# 2021-06-20 22:48:36,181 - DEBUG - Normalized params: oauth_consumer_key=pw0ihLFxH3nwDrd4HBd7pqUrc&oauth_nonce=174152913811685627841624218516&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1624218516&oauth_token=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz&oauth_version=1.0&screen_name=vasiange
# 2021-06-20 22:48:36,252 - DEBUG - Normalized URI: https://api.twitter.com/1.1/users/show.json
# 2021-06-20 22:48:36,260 - DEBUG - Signing: signature base string: GET&https%3A%2F%2Fapi.twitter.com%2F1.1%2Fusers%2Fshow.json&oauth_consumer_key%3Dpw0ihLFxH3nwDrd4HBd7pqUrc%26oauth_nonce%3D174152913811685627841624218516%26oauth_signature_method%3DHMAC-SHA1%26oauth_timestamp%3D1624218516%26oauth_token%3D1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz%26oauth_version%3D1.0%26screen_name%3Dvasiange
# 2021-06-20 22:48:36,264 - DEBUG - Signature: 9s7o49N8VOvSOYZUHxPKe0yM82Q=
# 2021-06-20 22:48:36,286 - DEBUG - Updated url: https://api.twitter.com/1.1/users/show.json?screen_name=vasiange
# 2021-06-20 22:48:36,292 - DEBUG - Updated headers: {'Host': 'api.twitter.com', 'Authorization': 'OAuth oauth_nonce="174152913811685627841624218516", oauth_timestamp="1624218516", oauth_version="1.0", oauth_signature_method="HMAC-SHA1", oauth_consumer_key="pw0ihLFxH3nwDrd4HBd7pqUrc", oauth_token="1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz", oauth_signature="9s7o49N8VOvSOYZUHxPKe0yM82Q%3D"'}
# 2021-06-20 22:48:36,321 - DEBUG - Updated body: None
# 2021-06-20 22:48:36,324 - DEBUG - Starting new HTTPS connection (1): api.twitter.com:443
# 2021-06-20 22:48:37,430 - DEBUG - https://api.twitter.com:443 "GET /1.1/users/show.json?screen_name=vasiange HTTP/1.1" 200 1319
# User(_api=<tweepy.api.API object at 0x7f7714101e10>, _json={'id': 1360011857969479682, 'id_str': '1360011857969479682', 'name': 'vasiange', 'screen_name': 'vasiange', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 15, 'listed_count': 0, 'created_at': 'Thu Feb 11 23:45:06 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [], 'suspended': False, 'needs_phone_verification': False}, id=1360011857969479682, id_str='1360011857969479682', name='vasiange', screen_name='vasiange', location='', profile_location=None, description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=0, friends_count=15, listed_count=0, created_at=datetime.datetime(2021, 2, 11, 23, 45, 6), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=True, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[], suspended=False, needs_phone_verification=False)

# %%
api.rate_limit_status()
# Out:
# 2021-06-21 13:45:23,452 - DEBUG - PARAMS: {}
# 2021-06-21 13:45:23,456 - DEBUG - Signing request <PreparedRequest [GET]> using client <Client client_key=pw0ihLFxH3nwDrd4HBd7pqUrc, client_secret=****, resource_owner_key=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# 2021-06-21 13:45:23,457 - DEBUG - Including body in call to sign: False
# 2021-06-21 13:45:23,458 - DEBUG - Collected params: [('oauth_nonce', '75468200399434852471624272323'), ('oauth_timestamp', '1624272323'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'pw0ihLFxH3nwDrd4HBd7pqUrc'), ('oauth_token', '1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz')]
# 2021-06-21 13:45:23,459 - DEBUG - Normalized params: oauth_consumer_key=pw0ihLFxH3nwDrd4HBd7pqUrc&oauth_nonce=75468200399434852471624272323&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1624272323&oauth_token=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz&oauth_version=1.0
# 2021-06-21 13:45:23,460 - DEBUG - Normalized URI: https://api.twitter.com/1.1/application/rate_limit_status.json
# 2021-06-21 13:45:23,461 - DEBUG - Signing: signature base string: GET&https%3A%2F%2Fapi.twitter.com%2F1.1%2Fapplication%2Frate_limit_status.json&oauth_consumer_key%3Dpw0ihLFxH3nwDrd4HBd7pqUrc%26oauth_nonce%3D75468200399434852471624272323%26oauth_signature_method%3DHMAC-SHA1%26oauth_timestamp%3D1624272323%26oauth_token%3D1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz%26oauth_version%3D1.0
# 2021-06-21 13:45:23,462 - DEBUG - Signature: 366Vh/0HzpasC9i5IGokmdFlcAA=
# 2021-06-21 13:45:23,466 - DEBUG - Updated url: https://api.twitter.com/1.1/application/rate_limit_status.json
# 2021-06-21 13:45:23,467 - DEBUG - Updated headers: {'Host': 'api.twitter.com', 'Authorization': 'OAuth oauth_nonce="75468200399434852471624272323", oauth_timestamp="1624272323", oauth_version="1.0", oauth_signature_method="HMAC-SHA1", oauth_consumer_key="pw0ihLFxH3nwDrd4HBd7pqUrc", oauth_token="1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz", oauth_signature="366Vh%2F0HzpasC9i5IGokmdFlcAA%3D"'}
# 2021-06-21 13:45:23,468 - DEBUG - Updated body: None
# 2021-06-21 13:45:23,471 - DEBUG - Starting new HTTPS connection (1): api.twitter.com:443
# 2021-06-21 13:45:25,178 - DEBUG - https://api.twitter.com:443 "GET /1.1/application/rate_limit_status.json HTTP/1.1" 200 18891
# eset': 1624273224},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1624273224}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1624273224},
#    '/guide/get_explore_locations': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/guide/explore_locations_with_autocomplete': {'limit': 200,
#     'remaining': 200,
#     'reset': 1624273224}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1624273224},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1624273224},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'users': {'/users/': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/:id': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/users/:source_user_id/blocking/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1624273224},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/:source_user_id/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/:id/tweets': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/:id/retweets/:source_tweet_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/:id/likes&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1624273224},
#    '/users/:id/retweets&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/users/by/username/:source_username/following/:target_user_name&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/by/username/:handle/tweets': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/users/:id/blocking&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/by/username/:source_username/following&POST': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/:id/followers': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/users/:id/following': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/users/:id/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/users/:source_user_id/following/:target_user_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/by/username/:username': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/users/by/username/:username/followers': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/:id/blocking': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/users/:id/likes/:tweet_id&DELETE': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/users/by/username/:username/following': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/users/by/username/:handle/mentions': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/users/by': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/users/:id/liked_tweets': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224}},
#   'teams': {'/teams/authorize': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224}},
#   'permissions': {'/permissions/user_permissions/admin_email_verification': {'limit': 3,
#     'remaining': 3,
#     'reset': 1624273224},
#    '/permissions/user_permissions': {'limit': 3,
#     'remaining': 3,
#     'reset': 1624273224}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1624273224},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1624273224}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1624273224},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224}},
#   'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#     'remaining': 5,
#     'reset': 1624273224},
#    '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#     'remaining': 10,
#     'reset': 1624273224},
#    '/labs/:version/tweets/stream/filter/': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/labs/:version/users/:id/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1624273224},
#    '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1624273224},
#    '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/labs/:version/tweets/stream/sample': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/labs/:version/users/by/username/:handle/tweets': {'limit': 225,
#     'remaining': 225,
#     'reset': 1624273224},
#    '/labs/:version/tweets/metrics/private': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/labs/:version/tweets/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/labs/:version/users/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/labs/:version/tweets/stream/compliance': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224},
#    '/labs/:version/tweets/search': {'limit': 225,
#     'remaining': 225,
#     'reset': 1624273224}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1624273224},
#    '/moments/create': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224}},
#   'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#     'remaining': 4500,
#     'reset': 1624273224}},
#   'fleets': {'/fleets/:version/mutes/create': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/viewers': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/delete': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/fleets/:version/avatar_content': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/create': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/fleets/:version/user_fleets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/fleets/:version/fleetline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/track_events': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/update': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/fleets/:version/fleet_threads': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224},
#    '/fleets/:version/mutes/list': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/mutes/destroy': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/home_timeline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1624273224},
#    '/fleets/:version/feedback/create': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224},
#    '/fleets/:version/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224}},
#   'graphql&POST': {'/graphql&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1624273224},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1624273224},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1624273224},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1624273224},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1624273224},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1624273224},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1624273224},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'strato': {'/strato/column/None/:id/cms/*': {'limit': 150,
#     'remaining': 150,
#     'reset': 1624273224}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1624273224},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/account/authenticate_web_view': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1624273224},
#    '/account/change_password': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1624273224}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'tweets': {'/tweets/search/all': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/tweets/search/stream/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/tweets/search/recent': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224},
#    '/tweets/sample/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/tweets/': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/tweets/counts/all': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/tweets/search/stream': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1624273224},
#    '/tweets/search/stream/rules/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/tweets/:tweet_id/liking_users': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/tweets/search/stream/rules&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/tweets/:id': {'limit': 900, 'remaining': 900, 'reset': 1624273224},
#    '/tweets/counts/recent': {'limit': 900,
#     'remaining': 900,
#     'reset': 1624273224},
#    '/tweets/search/stream/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/tweets/:id/hidden&PUT': {'limit': 50,
#     'remaining': 50,
#     'reset': 1624273224}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}},
#   'oauth': {'/oauth/revoke': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224},
#    '/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1624273224},
#    '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1624273224}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 24,
#     'reset': 1624272942}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1624273224},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1624273224},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1624273224}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1624273224}},
#   'graphql': {'/graphql': {'limit': 15,
#     'remaining': 15,
#     'reset': 1624273224}}}}

# %% [markdown]
# Now we setup dates. We need to setup today and yesterday.

# %%
today = datetime.date.today()
since= today - datetime.timedelta(days=2)
until= today
until, since
# (datetime.date(2021, 6, 7), datetime.date(2021, 6, 6))
# Out:
# (datetime.date(2021, 6, 21), datetime.date(2021, 6, 19))

# %%
    logger.debug(f"full_text: '{until, since}'")
# Out:
# 2021-06-22 02:34:50,212 - DEBUG - full_text: '(datetime.date(2021, 6, 21), datetime.date(2021, 6, 19))'

# %% [markdown]
# We search for tweets on Twitter by using the `Cursor()` function.
# We pass the `api.search` parameter to the cursor, as well as the query string, which is specified through the `q` parameter of the cursor.
# The query string can receive many parameters, such as the following (not mandatory) ones:
# * `from:` - to specify a specific Twitter user profile
# * `since:` - to specify the beginning date of search
# * `until:` - to specify the ending date of search
# The cursor can also receive other parameters, such as the language and the `tweet_mode`. If `tweet_mode='extended'`, all the text of the tweet is returned, otherwise only the first 140 characters.

# %%
# # example 
# code tweets = tweepy.Cursor(api.search, tweet_mode=’extended’) 
# for tweet in tweets:
#     content = tweet.full_text

# %%
# tweets_list = tweepy.Cursor(api.search, q="#Covid-19 since:" + str(yesterday)+ " until:" + str(today),tweet_mode='extended', lang='en').items()

# %%
# tweets_list = tweepy.Cursor(api.search, q=f"#Covid-19 since:{str(yesterday)} until:{str(today)}",tweet_mode='extended', lang='en').items()

# %%
tweets_list = tweepy.Cursor(api.search, q=['pfizer','astrazeneca'],since= str(since), until=str(until),tweet_mode='extended', lang='en').items()

# %% [markdown]
# Now we loop across the `tweets_list`, and, for each tweet, we extract the text, the creation date, the number of retweets and the favourite count. We store every tweet into a list, called `output`.

# %%
import time
seconds = 5
start = time.time()
time.sleep(seconds)
end = time.time()
logger.info(f"elapsed_time: '{end - start}'")
# Out:
# 2021-06-21 22:38:34,326 - INFO - elapsed_time: '5.005592107772827'

# %% [markdown]
# ---
# # TEST

# %% [markdown]
# ---

# %%
tweets_list2 = tweepy.Cursor(api.search, q=['pfizer','astrazeneca'],since= str(since), until=str(until),tweet_mode='extended', lang='en').items(2)

import time
start = time.time()
output = []
for tweet in tweets_list2:
    # text = tweet._json["full_text"]
    #print(text) 
    # https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/api-reference/get-search-tweets           
    # "geo": null,"coordinates": null,"place": null,"contributors": null,
    # "is_quote_status": false,"retweet_count": 988,"favorite_count": 3875,
    # "favorited": false,"retweeted": false,"possibly_sensitive": false,"lang": "en"
    logger.info(f"full_text: '{tweet.id}'")
    # favourite_count = tweet.favorite_count
    # retweet_count = tweet.retweet_count
    # created_at = tweet.created_at
    
#     line = {'text' : text, 'favourite_count' : favourite_count, 'retweet_count' : retweet_count, 'created_at' : created_at}
#     output.append(line)
#     logger.info(f"Append list length : { len(output)}")
# end = time.time()
# logger.info(f"elapsed_time: '{end - start}'")
# Out:
# 2021-06-22 02:18:48,749 - DEBUG - PARAMS: {'q': b"['pfizer', 'astrazeneca']", 'since': b'2021-06-19', 'until': b'2021-06-21', 'tweet_mode': b'extended', 'lang': b'en'}
# 2021-06-22 02:18:48,756 - DEBUG - Signing request <PreparedRequest [GET]> using client <Client client_key=pw0ihLFxH3nwDrd4HBd7pqUrc, client_secret=****, resource_owner_key=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# 2021-06-22 02:18:48,762 - DEBUG - Including body in call to sign: False
# 2021-06-22 02:18:48,767 - DEBUG - Collected params: [('q', "['pfizer', 'astrazeneca']"), ('since', '2021-06-19'), ('until', '2021-06-21'), ('tweet_mode', 'extended'), ('lang', 'en'), ('oauth_nonce', '80562232051496740461624317528'), ('oauth_timestamp', '1624317528'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'pw0ihLFxH3nwDrd4HBd7pqUrc'), ('oauth_token', '1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz')]
# 2021-06-22 02:18:48,773 - DEBUG - Normalized params: lang=en&oauth_consumer_key=pw0ihLFxH3nwDrd4HBd7pqUrc&oauth_nonce=80562232051496740461624317528&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1624317528&oauth_token=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz&oauth_version=1.0&q=%5B%27pfizer%27%2C%20%27astrazeneca%27%5D&since=2021-06-19&tweet_mode=extended&until=2021-06-21
# 2021-06-22 02:18:48,774 - DEBUG - Normalized URI: https://api.twitter.com/1.1/search/tweets.json
# 2021-06-22 02:18:48,776 - DEBUG - Signing: signature base string: GET&https%3A%2F%2Fapi.twitter.com%2F1.1%2Fsearch%2Ftweets.json&lang%3Den%26oauth_consumer_key%3Dpw0ihLFxH3nwDrd4HBd7pqUrc%26oauth_nonce%3D80562232051496740461624317528%26oauth_signature_method%3DHMAC-SHA1%26oauth_timestamp%3D1624317528%26oauth_token%3D1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz%26oauth_version%3D1.0%26q%3D%255B%2527pfizer%2527%252C%2520%2527astrazeneca%2527%255D%26since%3D2021-06-19%26tweet_mode%3Dextended%26until%3D2021-06-21
# 2021-06-22 02:18:48,785 - DEBUG - Signature: OQT2K4J/lwBsSGlV/hMgmwutEYo=
# 2021-06-22 02:18:48,791 - DEBUG - Updated url: https://api.twitter.com/1.1/search/tweets.json?q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en
# 2021-06-22 02:18:48,792 - DEBUG - Updated headers: {'Host': 'api.twitter.com', 'Authorization': 'OAuth oauth_nonce="80562232051496740461624317528", oauth_timestamp="1624317528", oauth_version="1.0", oauth_signature_method="HMAC-SHA1", oauth_consumer_key="pw0ihLFxH3nwDrd4HBd7pqUrc", oauth_token="1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz", oauth_signature="OQT2K4J%2FlwBsSGlV%2FhMgmwutEYo%3D"'}
# 2021-06-22 02:18:48,800 - DEBUG - Updated body: None
# 2021-06-22 02:18:48,803 - DEBUG - Starting new HTTPS connection (1): api.twitter.com:443
# 2021-06-22 02:18:49,791 - DEBUG - https://api.twitter.com:443 "GET /1.1/search/tweets.json?q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en HTTP/1.1" 200 90367
# 2021-06-22 02:18:49,898 - DEBUG - PARAMS: {'create': b'True'}
# 2021-06-22 02:18:49,908 - INFO - full_text: '1406763765094404100'
# 2021-06-22 02:18:49,920 - INFO - full_text: '1406763702301433857'

# %% [markdown]
# ---

# %%
import time
start = time.time()
output = []
for tweet in tweets_list:
    text = tweet._json["full_text"]
    #print(text) 
    # https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/api-reference/get-search-tweets           
    # "geo": null,"coordinates": null,"place": null,"contributors": null,
    # "is_quote_status": false,"retweet_count": 988,"favorite_count": 3875,
    # "favorited": false,"retweeted": false,"possibly_sensitive": false,"lang": "en"
    logger.debug(f"full_text: '{text}'")
    favourite_count = tweet.favorite_count
    retweet_count = tweet.retweet_count
    created_at = tweet.created_at
    
    line = {'text' : text, 'favourite_count' : favourite_count, 'retweet_count' : retweet_count, 'created_at' : created_at}
    output.append(line)
    logger.info(f"Append list length : { len(output)}")
end = time.time()
logger.info(f"elapsed_time: '{end - start}'")
# Out:
#  Scott Morrison and Greg Hunt said no and put all their…'
# 2021-06-21 16:01:13,058 - INFO - Append list length : 6471
# 2021-06-21 16:01:13,066 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,071 - INFO - Append list length : 6472
# 2021-06-21 16:01:13,072 - DEBUG - full_text: 'RT @JohnRHewson: Talk about making the best of a bad call - claiming that those aged 50-60 who were hesitant about getting the AstraZeneca…'
# 2021-06-21 16:01:13,073 - INFO - Append list length : 6473
# 2021-06-21 16:01:13,077 - DEBUG - full_text: 'RT @Fiona_M_Russell: I am over 50 &amp; had my first AstraZeneca vaccine dose &amp; plan on getting my second dose next month. Two doses provide &gt;9…'
# 2021-06-21 16:01:13,084 - INFO - Append list length : 6474
# 2021-06-21 16:01:13,091 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,093 - INFO - Append list length : 6475
# 2021-06-21 16:01:13,094 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,095 - INFO - Append list length : 6476
# 2021-06-21 16:01:13,099 - DEBUG - full_text: 'RT @jburnmurdoch: Here’s the key table from @PHE_uk new report on vaccine efficacy against hospitalisation with Delta variant:
#
# After 1 dos…'
# 2021-06-21 16:01:13,102 - INFO - Append list length : 6477
# 2021-06-21 16:01:13,103 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,106 - INFO - Append list length : 6478
# 2021-06-21 16:01:13,109 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,110 - INFO - Append list length : 6479
# 2021-06-21 16:01:13,112 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,116 - INFO - Append list length : 6480
# 2021-06-21 16:01:13,116 - DEBUG - full_text: 'RT @drvyom: Both my parents will get their 2nd dose of AstraZeneca. Skipping it would be madness.
# Yes Spain/uk are trialling Pfizer/Az reg…'
# 2021-06-21 16:01:13,117 - INFO - Append list length : 6481
# 2021-06-21 16:01:13,117 - DEBUG - full_text: 'The experts at the Australian Technical Advisory Group on Immunisation (ATAGI) have updated their advice to recommend the Pfizer vaccine be preferred for adults aged 59 and under. https://t.co/34CZtIece5 https://t.co/3CT1Nf8n7W'
# 2021-06-21 16:01:13,135 - INFO - Append list length : 6482
# 2021-06-21 16:01:13,136 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,137 - INFO - Append list length : 6483
# 2021-06-21 16:01:13,138 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:13,138 - INFO - Append list length : 6484
# 2021-06-21 16:01:13,140 - DEBUG - full_text: 'RT @SwannyQLD: More mixed messages .
# “Canada’s national immunisation advisory body recommended provincial governments stop administering As…'
# 2021-06-21 16:01:13,142 - INFO - Append list length : 6485
# 2021-06-21 16:01:13,143 - DEBUG - PARAMS: {'max_id': b'1406041083134414848', 'q': b"['pfizer', 'astrazeneca']", 'since': b'2021-06-19', 'until': b'2021-06-21', 'tweet_mode': b'extended', 'lang': b'en'}
# 2021-06-21 16:01:13,154 - DEBUG - Signing request <PreparedRequest [GET]> using client <Client client_key=pw0ihLFxH3nwDrd4HBd7pqUrc, client_secret=****, resource_owner_key=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# 2021-06-21 16:01:13,158 - DEBUG - Including body in call to sign: False
# 2021-06-21 16:01:13,165 - DEBUG - Collected params: [('max_id', '1406041083134414848'), ('q', "['pfizer', 'astrazeneca']"), ('since', '2021-06-19'), ('until', '2021-06-21'), ('tweet_mode', 'extended'), ('lang', 'en'), ('oauth_nonce', '10722183371707728401624280473'), ('oauth_timestamp', '1624280473'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'pw0ihLFxH3nwDrd4HBd7pqUrc'), ('oauth_token', '1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz')]
# 2021-06-21 16:01:13,168 - DEBUG - Normalized params: lang=en&max_id=1406041083134414848&oauth_consumer_key=pw0ihLFxH3nwDrd4HBd7pqUrc&oauth_nonce=10722183371707728401624280473&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1624280473&oauth_token=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz&oauth_version=1.0&q=%5B%27pfizer%27%2C%20%27astrazeneca%27%5D&since=2021-06-19&tweet_mode=extended&until=2021-06-21
# 2021-06-21 16:01:13,177 - DEBUG - Normalized URI: https://api.twitter.com/1.1/search/tweets.json
# 2021-06-21 16:01:13,178 - DEBUG - Signing: signature base string: GET&https%3A%2F%2Fapi.twitter.com%2F1.1%2Fsearch%2Ftweets.json&lang%3Den%26max_id%3D1406041083134414848%26oauth_consumer_key%3Dpw0ihLFxH3nwDrd4HBd7pqUrc%26oauth_nonce%3D10722183371707728401624280473%26oauth_signature_method%3DHMAC-SHA1%26oauth_timestamp%3D1624280473%26oauth_token%3D1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz%26oauth_version%3D1.0%26q%3D%255B%2527pfizer%2527%252C%2520%2527astrazeneca%2527%255D%26since%3D2021-06-19%26tweet_mode%3Dextended%26until%3D2021-06-21
# 2021-06-21 16:01:13,179 - DEBUG - Signature: p7/fbMsbPTpZNPKO/QVKmoOi5TA=
# 2021-06-21 16:01:13,180 - DEBUG - Updated url: https://api.twitter.com/1.1/search/tweets.json?max_id=1406041083134414848&q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en
# 2021-06-21 16:01:13,182 - DEBUG - Updated headers: {'Host': 'api.twitter.com', 'Cookie': 'guest_id=v1%3A162427891517705747; personalization_id="v1_JvGKKD0uWWlvXItTtxnf4g=="', 'Authorization': 'OAuth oauth_nonce="10722183371707728401624280473", oauth_timestamp="1624280473", oauth_version="1.0", oauth_signature_method="HMAC-SHA1", oauth_consumer_key="pw0ihLFxH3nwDrd4HBd7pqUrc", oauth_token="1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz", oauth_signature="p7%2FfbMsbPTpZNPKO%2FQVKmoOi5TA%3D"'}
# 2021-06-21 16:01:13,188 - DEBUG - Updated body: None
# 2021-06-21 16:01:13,192 - DEBUG - Starting new HTTPS connection (1): api.twitter.com:443
# 2021-06-21 16:01:14,826 - DEBUG - https://api.twitter.com:443 "GET /1.1/search/tweets.json?max_id=1406041083134414848&q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en HTTP/1.1" 200 74251
# 2021-06-21 16:01:14,970 - DEBUG - PARAMS: {'create': b'True'}
# 2021-06-21 16:01:14,998 - DEBUG - full_text: 'RT @JohnRHewson: Talk about making the best of a bad call - claiming that those aged 50-60 who were hesitant about getting the AstraZeneca…'
# 2021-06-21 16:01:15,002 - INFO - Append list length : 6486
# 2021-06-21 16:01:15,003 - DEBUG - full_text: 'RT @JohnRHewson: Talk about making the best of a bad call - claiming that those aged 50-60 who were hesitant about getting the AstraZeneca…'
# 2021-06-21 16:01:15,010 - INFO - Append list length : 6487
# 2021-06-21 16:01:15,011 - DEBUG - full_text: 'Latest Public Health England data on Delta Variant, curtesy of @azlina_ox
# Despite rising numbers, admissions and some deaths, protection by vaccination looks promising.
# UK using AstraZeneca &amp; Pfizer. https://t.co/WOYdSmX4Iz'
# 2021-06-21 16:01:15,012 - INFO - Append list length : 6488
# 2021-06-21 16:01:15,013 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,014 - INFO - Append list length : 6489
# 2021-06-21 16:01:15,016 - DEBUG - full_text: '@wordfalcon @eosull @darrengrimes_ @AstraZeneca Tell me how much the Pfizer vaccine is to these countries. These other countries have brought in much bigger bulk and some countries have invested. Morals coming from you, context matters.'
# 2021-06-21 16:01:15,016 - INFO - Append list length : 6490
# 2021-06-21 16:01:15,017 - DEBUG - full_text: 'RT @ThaiEnquirer: One dose of AstraZeneca or Pfizer can reduce the risk of hospitalization by 75%, British health officials said.
#
# #แอสตร้า…'
# 2021-06-21 16:01:15,031 - INFO - Append list length : 6491
# 2021-06-21 16:01:15,031 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,032 - INFO - Append list length : 6492
# 2021-06-21 16:01:15,034 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,035 - INFO - Append list length : 6493
# 2021-06-21 16:01:15,036 - DEBUG - full_text: 'RT @joshburnsmp: Pfizer offered Australia as many vaccines as we needed but instead Scott Morrison and Greg Hunt said no and put all their…'
# 2021-06-21 16:01:15,036 - INFO - Append list length : 6494
# 2021-06-21 16:01:15,040 - DEBUG - full_text: '2/2 AstraZeneca patients can choose to get AZ as their second dose or an mRNA like Pfizer or Moderna.  @AlbanyClinic will be offering Moderna next Thursday June 24 to AZ first dose pts'
# 2021-06-21 16:01:15,044 - INFO - Append list length : 6495
# 2021-06-21 16:01:15,053 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,053 - INFO - Append list length : 6496
# 2021-06-21 16:01:15,054 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,054 - INFO - Append list length : 6497
# 2021-06-21 16:01:15,056 - DEBUG - full_text: 'RT @drvyom: Both my parents will get their 2nd dose of AstraZeneca. Skipping it would be madness.
# Yes Spain/uk are trialling Pfizer/Az reg…'
# 2021-06-21 16:01:15,056 - INFO - Append list length : 6498
# 2021-06-21 16:01:15,057 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,057 - INFO - Append list length : 6499
# 2021-06-21 16:01:15,058 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:15,058 - INFO - Append list length : 6500
# 2021-06-21 16:01:15,059 - DEBUG - PARAMS: {'max_id': b'1406040058440806407', 'q': b"['pfizer', 'astrazeneca']", 'since': b'2021-06-19', 'until': b'2021-06-21', 'tweet_mode': b'extended', 'lang': b'en'}
# 2021-06-21 16:01:15,060 - DEBUG - Signing request <PreparedRequest [GET]> using client <Client client_key=pw0ihLFxH3nwDrd4HBd7pqUrc, client_secret=****, resource_owner_key=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# 2021-06-21 16:01:15,064 - DEBUG - Including body in call to sign: False
# 2021-06-21 16:01:15,067 - DEBUG - Collected params: [('max_id', '1406040058440806407'), ('q', "['pfizer', 'astrazeneca']"), ('since', '2021-06-19'), ('until', '2021-06-21'), ('tweet_mode', 'extended'), ('lang', 'en'), ('oauth_nonce', '144057624898467564611624280475'), ('oauth_timestamp', '1624280475'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'pw0ihLFxH3nwDrd4HBd7pqUrc'), ('oauth_token', '1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz')]
# 2021-06-21 16:01:15,074 - DEBUG - Normalized params: lang=en&max_id=1406040058440806407&oauth_consumer_key=pw0ihLFxH3nwDrd4HBd7pqUrc&oauth_nonce=144057624898467564611624280475&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1624280475&oauth_token=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz&oauth_version=1.0&q=%5B%27pfizer%27%2C%20%27astrazeneca%27%5D&since=2021-06-19&tweet_mode=extended&until=2021-06-21
# 2021-06-21 16:01:15,078 - DEBUG - Normalized URI: https://api.twitter.com/1.1/search/tweets.json
# 2021-06-21 16:01:15,084 - DEBUG - Signing: signature base string: GET&https%3A%2F%2Fapi.twitter.com%2F1.1%2Fsearch%2Ftweets.json&lang%3Den%26max_id%3D1406040058440806407%26oauth_consumer_key%3Dpw0ihLFxH3nwDrd4HBd7pqUrc%26oauth_nonce%3D144057624898467564611624280475%26oauth_signature_method%3DHMAC-SHA1%26oauth_timestamp%3D1624280475%26oauth_token%3D1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz%26oauth_version%3D1.0%26q%3D%255B%2527pfizer%2527%252C%2520%2527astrazeneca%2527%255D%26since%3D2021-06-19%26tweet_mode%3Dextended%26until%3D2021-06-21
# 2021-06-21 16:01:15,084 - DEBUG - Signature: oBpfhI002lffzsyldLeZHMpXUoY=
# 2021-06-21 16:01:15,085 - DEBUG - Updated url: https://api.twitter.com/1.1/search/tweets.json?max_id=1406040058440806407&q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en
# 2021-06-21 16:01:15,086 - DEBUG - Updated headers: {'Host': 'api.twitter.com', 'Cookie': 'guest_id=v1%3A162427891517705747; personalization_id="v1_JvGKKD0uWWlvXItTtxnf4g=="', 'Authorization': 'OAuth oauth_nonce="144057624898467564611624280475", oauth_timestamp="1624280475", oauth_version="1.0", oauth_signature_method="HMAC-SHA1", oauth_consumer_key="pw0ihLFxH3nwDrd4HBd7pqUrc", oauth_token="1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz", oauth_signature="oBpfhI002lffzsyldLeZHMpXUoY%3D"'}
# 2021-06-21 16:01:15,086 - DEBUG - Updated body: None
# 2021-06-21 16:01:15,088 - DEBUG - Starting new HTTPS connection (1): api.twitter.com:443
# 2021-06-21 16:01:16,972 - DEBUG - https://api.twitter.com:443 "GET /1.1/search/tweets.json?max_id=1406040058440806407&q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en HTTP/1.1" 200 52179
# 2021-06-21 16:01:17,129 - DEBUG - PARAMS: {'create': b'True'}
# 2021-06-21 16:01:17,135 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:17,137 - INFO - Append list length : 6501
# 2021-06-21 16:01:17,138 - DEBUG - full_text: 'RT @CraigKellyMP: What an incompetent clown show 🤡🤡🤡
#
# More than 800,000 thousands have been injected with a novel experimental genetic agen…'
# 2021-06-21 16:01:17,139 - INFO - Append list length : 6502
# 2021-06-21 16:01:17,140 - DEBUG - full_text: 'RT @JohnRHewson: Talk about making the best of a bad call - claiming that those aged 50-60 who were hesitant about getting the AstraZeneca…'
# 2021-06-21 16:01:17,141 - INFO - Append list length : 6503
# 2021-06-21 16:01:17,142 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:17,143 - INFO - Append list length : 6504
# 2021-06-21 16:01:17,144 - DEBUG - full_text: 'RT @joshburnsmp: Pfizer offered Australia as many vaccines as we needed but instead Scott Morrison and Greg Hunt said no and put all their…'
# 2021-06-21 16:01:17,145 - INFO - Append list length : 6505
# 2021-06-21 16:01:17,146 - DEBUG - full_text: '@Fab485617452 @JohnRHewson I'm 73 and my wife is 62... we will only accept the Pfizer vaccination, regardless of what the pseudo-medical experts say about our being eligible only for AstraZeneca. And so we wait...'
# 2021-06-21 16:01:17,148 - INFO - Append list length : 6506
# 2021-06-21 16:01:17,150 - DEBUG - full_text: 'RT @kyle_minogue: @bjornradstrom Pfizer - 12-15 yrs old (tested already)
# Pfizer -testing 5 to 11yrs old
# Pfizer -  Data available for ages 5…'
# 2021-06-21 16:01:17,151 - INFO - Append list length : 6507
# 2021-06-21 16:01:17,151 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:17,152 - INFO - Append list length : 6508
# 2021-06-21 16:01:17,153 - DEBUG - full_text: 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?'
# 2021-06-21 16:01:17,153 - INFO - Append list length : 6509
# 2021-06-21 16:01:17,154 - DEBUG - full_text: 'RT @DrEricDing: 3) “After years of reading research on mixing vaccine types -- known as heterologous prime-boosting -- Morgon concluded tha…'
# 2021-06-21 16:01:17,154 - INFO - Append list length : 6510
# 2021-06-21 16:01:17,155 - DEBUG - PARAMS: {'max_id': b'1406039056975335423', 'q': b"['pfizer', 'astrazeneca']", 'since': b'2021-06-19', 'until': b'2021-06-21', 'tweet_mode': b'extended', 'lang': b'en'}
# 2021-06-21 16:01:17,157 - DEBUG - Signing request <PreparedRequest [GET]> using client <Client client_key=pw0ihLFxH3nwDrd4HBd7pqUrc, client_secret=****, resource_owner_key=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz, resource_owner_secret=****, signature_method=HMAC-SHA1, signature_type=AUTH_HEADER, callback_uri=None, rsa_key=None, verifier=None, realm=None, encoding=utf-8, decoding=None, nonce=None, timestamp=None>
# 2021-06-21 16:01:17,159 - DEBUG - Including body in call to sign: False
# 2021-06-21 16:01:17,160 - DEBUG - Collected params: [('max_id', '1406039056975335423'), ('q', "['pfizer', 'astrazeneca']"), ('since', '2021-06-19'), ('until', '2021-06-21'), ('tweet_mode', 'extended'), ('lang', 'en'), ('oauth_nonce', '111803701029869509101624280477'), ('oauth_timestamp', '1624280477'), ('oauth_version', '1.0'), ('oauth_signature_method', 'HMAC-SHA1'), ('oauth_consumer_key', 'pw0ihLFxH3nwDrd4HBd7pqUrc'), ('oauth_token', '1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz')]
# 2021-06-21 16:01:17,162 - DEBUG - Normalized params: lang=en&max_id=1406039056975335423&oauth_consumer_key=pw0ihLFxH3nwDrd4HBd7pqUrc&oauth_nonce=111803701029869509101624280477&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1624280477&oauth_token=1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz&oauth_version=1.0&q=%5B%27pfizer%27%2C%20%27astrazeneca%27%5D&since=2021-06-19&tweet_mode=extended&until=2021-06-21
# 2021-06-21 16:01:17,163 - DEBUG - Normalized URI: https://api.twitter.com/1.1/search/tweets.json
# 2021-06-21 16:01:17,163 - DEBUG - Signing: signature base string: GET&https%3A%2F%2Fapi.twitter.com%2F1.1%2Fsearch%2Ftweets.json&lang%3Den%26max_id%3D1406039056975335423%26oauth_consumer_key%3Dpw0ihLFxH3nwDrd4HBd7pqUrc%26oauth_nonce%3D111803701029869509101624280477%26oauth_signature_method%3DHMAC-SHA1%26oauth_timestamp%3D1624280477%26oauth_token%3D1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz%26oauth_version%3D1.0%26q%3D%255B%2527pfizer%2527%252C%2520%2527astrazeneca%2527%255D%26since%3D2021-06-19%26tweet_mode%3Dextended%26until%3D2021-06-21
# 2021-06-21 16:01:17,164 - DEBUG - Signature: fDq+9oMc5bk3ECzv5ybpXPJZe4s=
# 2021-06-21 16:01:17,165 - DEBUG - Updated url: https://api.twitter.com/1.1/search/tweets.json?max_id=1406039056975335423&q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en
# 2021-06-21 16:01:17,171 - DEBUG - Updated headers: {'Host': 'api.twitter.com', 'Cookie': 'guest_id=v1%3A162427891517705747; personalization_id="v1_JvGKKD0uWWlvXItTtxnf4g=="', 'Authorization': 'OAuth oauth_nonce="111803701029869509101624280477", oauth_timestamp="1624280477", oauth_version="1.0", oauth_signature_method="HMAC-SHA1", oauth_consumer_key="pw0ihLFxH3nwDrd4HBd7pqUrc", oauth_token="1360011857969479682-iLrxBUlqdtExwkqiN9iZsHYDXIFTZz", oauth_signature="fDq%2B9oMc5bk3ECzv5ybpXPJZe4s%3D"'}
# 2021-06-21 16:01:17,174 - DEBUG - Updated body: None
# 2021-06-21 16:01:17,182 - DEBUG - Starting new HTTPS connection (1): api.twitter.com:443
# 2021-06-21 16:01:18,616 - DEBUG - https://api.twitter.com:443 "GET /1.1/search/tweets.json?max_id=1406039056975335423&q=%5B%27pfizer%27%2C+%27astrazeneca%27%5D&since=2021-06-19&until=2021-06-21&tweet_mode=extended&lang=en HTTP/1.1" 200 410
# 2021-06-21 16:01:18,636 - DEBUG - PARAMS: {'create': b'True'}
# 2021-06-21 16:01:18,902 - INFO - elapsed_time: '1501.7983951568604'

# %%
output
# Out:
# 19, 43)},
#  {'text': 'Good morning #YXE - the walk-in clinic at Prairieland will have AstraZeneca (2nd dose) and Moderna (1st dose) today. The drive-thru has Pfizer (1st or 2nd dose). For the latest info visit https://t.co/Mh44eNmrrF.',
#   'favourite_count': 43,
#   'retweet_count': 27,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 19, 36)},
#  {'text': 'RT @NorthLincsCNews: Walk-in Covid-19 jabs are available at the Crosby ONE Centre in a pop-up vaccination clinic on Tuesday 22 June.\nNo app…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 19, 26)},
#  {'text': 'RT @DrEricDing: 13) Vaccine effectiveness against #DeltaVariant according to @PHE_uk — averaging AstraZeneca &amp; Pfizer together (even if dif…',
#   'favourite_count': 0,
#   'retweet_count': 94,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 19, 4)},
#  {'text': 'RT @JoannaBlythman: Official data, obtained by the Sunday Times, show that the MHRA received 2,734 reports of period problems linked to the…',
#   'favourite_count': 0,
#   'retweet_count': 19,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 17, 51)},
#  {'text': 'RT @TheRustler83: 3,752 people have died in Scotland, within 28 days of a vaxxine 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f💉....\n\n1,289 deaths after #Pfizer\n2,461 deaths aft…',
#   'favourite_count': 0,
#   'retweet_count': 1307,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 17, 32)},
#  {'text': '13) Vaccine effectiveness against #DeltaVariant according to @PHE_uk — averaging AstraZeneca &amp; Pfizer together (even if different), you can see a substantial drop for 1 dose. But even 2 doses has a ~8% drop as well. Also AZ’s 2 dose is actually 60%. \nhttps://t.co/QBWhP4neLL https://t.co/VCIQzkXqIm',
#   'favourite_count': 183,
#   'retweet_count': 94,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 16, 50)},
#  {'text': 'RT @lizamariiie: People complaining that Davao got a “lion’s share” of Pfizer vaccine. What’s your source? And did we ever complain when th…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 15, 51)},
#  {'text': 'Why wait for delta variant to take hold! Offer second jab of Pfizer to all that already have astrazeneca as first dose. Smart...',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 15, 43)},
#  {'text': 'https://t.co/T2VzFswt5U Dê Like\n219 | Top 10 By Pipeline Size - Pharma Companies\n✔ Brazil SFE Company®\n\n@Novartis\n@Takeda\n@Johnson&amp;Johnson\n@AstraZeneca\n@Sanofi\n@Roche\n@GSK\n@Merck\n@Pfizer\n@EliLilly https://t.co/jDD9dShYHp',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 15, 14)},
#  {'text': 'RT @JoannaBlythman: Official data, obtained by the Sunday Times, show that the MHRA received 2,734 reports of period problems linked to the…',
#   'favourite_count': 0,
#   'retweet_count': 19,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 13, 53)},
#  {'text': 'RT @SteveFitSmart: @InsidersABC #insiders \n...if we take AstraZeneca out of the equation ie. Under 60, there is no other vaccine available…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 13, 48)},
#  {'text': 'RT @NorthLincsCNews: Walk-in Covid-19 jabs are available at the Crosby ONE Centre in a pop-up vaccination clinic on Tuesday 22 June.\nNo app…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 13, 11)},
#  {'text': "RT @ShiannonC: 'Pfizer wanted to make an example out of Aus last June abt how 2 properly conduct a vaccine rollout. We could hve had 40m do…",
#   'favourite_count': 0,
#   'retweet_count': 39,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 9, 42)},
#  {'text': "The irony that #Pfizer(more asset-stripper than pharmaceutical innovator IMO)will benefit by $73bn till 2023&amp;may have enough cash to buy up #AstraZeneca's non-profit Cov-19 vacc. &amp;research labs[competitor, as they are]&amp;close them all down-as they have done in the past-is palpable",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 8, 51)},
#  {'text': 'RT @JoannaBlythman: Official data, obtained by the Sunday Times, show that the MHRA received 2,734 reports of period problems linked to the…',
#   'favourite_count': 0,
#   'retweet_count': 19,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 7, 45)},
#  {'text': 'RT @thewire_in: PHE said that the Pfizer/Biontech COVID-19 vaccine was 96% effective against hospitalisation from the delta variant after t…',
#   'favourite_count': 0,
#   'retweet_count': 18,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 7, 35)},
#  {'text': 'RT @thewire_in: PHE said that the Pfizer/Biontech COVID-19 vaccine was 96% effective against hospitalisation from the delta variant after t…',
#   'favourite_count': 0,
#   'retweet_count': 18,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 7, 14)},
#  {'text': "RT @Siobhain_Mc: PLEASE SPREAD THE WORD!\n\n8 hours left at Morden's pop up vaccine hub: @OfficialTmufc, Bishopford Road, SM4 6BF\n\nNo queue!…",
#   'favourite_count': 0,
#   'retweet_count': 47,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 6, 44)},
#  {'text': 'RT @julesserkin: @carlaf_to @user96603761 @jojojojoos @AstraZeneca @pfizer @H_Higginson44 @hibbsy1973 My neurologist said he’d seen 2 women…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 6, 26)},
#  {'text': 'RT @LowyatNET: Khairy Jamaluddin: Mixing Of #AstraZeneca And #Pfizer Vaccines A Possibility\n\nhttps://t.co/9T5PHCGCNc https://t.co/f8wOkPZxQf',
#   'favourite_count': 0,
#   'retweet_count': 13,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 5, 14)},
#  {'text': "RT @Siobhain_Mc: PLEASE SPREAD THE WORD!\n\n8 hours left at Morden's pop up vaccine hub: @OfficialTmufc, Bishopford Road, SM4 6BF\n\nNo queue!…",
#   'favourite_count': 0,
#   'retweet_count': 47,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 5, 3)},
#  {'text': 'RT @JoannaBlythman: Official data, obtained by the Sunday Times, show that the MHRA received 2,734 reports of period problems linked to the…',
#   'favourite_count': 0,
#   'retweet_count': 19,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 5, 2)},
#  {'text': 'Walk-in Covid-19 jabs are available at the Crosby ONE Centre in a pop-up vaccination clinic on Tuesday 22 June.\nNo appointment necessary, the Digby Street centre in Scunthorpe (DN15 7LU) is open 8.30am-4pm.\nBoth AstraZeneca and Pfizer vaccines are available, first doses only. https://t.co/9dfJr68lt3',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 5)},
#  {'text': 'Official data, obtained by the Sunday Times, show that the MHRA received 2,734 reports of period problems linked to the AstraZeneca vaccine, 1,158 related to the Pfizer jab, and 66 linked to the Moderna vaccine up to May 17th. https://t.co/r348EbttTu',
#   'favourite_count': 35,
#   'retweet_count': 19,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 4, 39)},
#  {'text': "RT @Siobhain_Mc: PLEASE SPREAD THE WORD!\n\n8 hours left at Morden's pop up vaccine hub: @OfficialTmufc, Bishopford Road, SM4 6BF\n\nNo queue!…",
#   'favourite_count': 0,
#   'retweet_count': 47,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 4, 38)},
#  {'text': 'RT @abirballan: Relative Risk Reduction (RRR) vs Absolute Risk Reduction of vaccines (ARR) of vaccines.\nRRR reported by vaccine manufacture…',
#   'favourite_count': 0,
#   'retweet_count': 55,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 3, 46)},
#  {'text': 'RT @Saints_Dragons: This was an absolutely appalling decision by Morrison. They refused Pfizer offer of 40 million doses claiming AstraZene…',
#   'favourite_count': 0,
#   'retweet_count': 231,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 1, 6)},
#  {'text': "UP is already a pioneer in this. They mixed Covishield with Covaxin for 20 people.😎\n\n'Vaccinating with AstraZeneca &amp; Pfizer vaccines produces a potent immune response against the virus, researchers conducting a study in Spain have found.' \nhttps://t.co/jy1EAkolmT",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 1, 3)},
#  {'text': 'Money behind anti #AstraZeneca , it costs $4 US vs Pfizer at $20 . Read https://t.co/fTmdzKesx1 https://t.co/jCDIpyzSJQ',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 14, 0, 52)},
#  {'text': 'RT @thewire_in: PHE said that the Pfizer/Biontech COVID-19 vaccine was 96% effective against hospitalisation from the delta variant after t…',
#   'favourite_count': 0,
#   'retweet_count': 18,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 59, 18)},
#  {'text': '@BristOliver If the Pfizer and AstraZeneca Vaccines are 96% and 92% effective against Hospitalisation after 2 doses how does this effect future predictions?\nhttps://t.co/WYYoOSDjBz',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 56, 52)},
#  {'text': '@DrEricDing @GosiaGasperoPhD thats astrazeneca is useless shit,,  thats it!!  plz change vaccine,,  pfizer efficacy is not 88% delta variant its biggest lie,,  its around 75% not 88%!',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 55, 17)},
#  {'text': 'RT @MFTnhs: ‼️ We have walk-in vaccine slots free 𝗧𝗢𝗗𝗔𝗬 for over 18s. ‼️\n\nℹ️ Head to the @MFT_MRI walk-in from 9am-4pm Saturday and Sunday.…',
#   'favourite_count': 0,
#   'retweet_count': 28,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 54, 5)},
#  {'text': '@DrEricDing thats astrazeneca is useless shit,,  thats it!!  plz change vaccine,,  pfizer efficacy is not 88% delta variant its biggest lie,,  its around 75% not 88%!',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 52, 7)},
#  {'text': 'RT @eatatjoe2: This is a story that received very little exposure in OZ media. I wonder why? Sounds totally relevant to discussions about A…',
#   'favourite_count': 0,
#   'retweet_count': 68,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 51, 20)},
#  {'text': "RT @Siobhain_Mc: PLEASE SPREAD THE WORD!\n\n8 hours left at Morden's pop up vaccine hub: @OfficialTmufc, Bishopford Road, SM4 6BF\n\nNo queue!…",
#   'favourite_count': 0,
#   'retweet_count': 47,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 49, 53)},
#  {'text': '@Telegraph Real effectiveness of vaccines:\n"ARRs: 1·3% for the AstraZeneca–Oxford, 1·2% for the Moderna–NIH, 1·2% for the J&amp;J, 0·93% for the Gamaleya, and 0·84% for the Pfizer–BioNTech vaccines.\nSource:\nhttps://t.co/6lhNnhHeXM',
#   'favourite_count': 1,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 48, 4)},
#  {'text': "RT @ShiannonC: 'Pfizer wanted to make an example out of Aus last June abt how 2 properly conduct a vaccine rollout. We could hve had 40m do…",
#   'favourite_count': 0,
#   'retweet_count': 39,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 46, 42)},
#  {'text': 'Allow 12 weeks between vaccines (&gt; effective) and we could start giving mRNA vax to ALL.\nAt LEAST offer #Pfizer as a 2nd dose to those who had 1st #AstraZeneca.   #QandA #TheDrum @InsidersABC @abcnews #covidaus @AlboMP @ScottMorrisonMP @GregHuntMP @Mark_Butler_MP',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 45, 37)},
#  {'text': "But of course this hasn't happened and is extremely unlikely.\n\nHowever, given the escape tendencies of B.1.617.2, Pfizer and AstraZeneca should probably start spinning up boosters against this particular variant.",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 45, 26)},
#  {'text': 'RT @Mana54419246: Appalling decision by #MorrisonGovernment #Pfizer offered 40 million doses claiming AstraZeneca was cheaper. #PfizerVacci…',
#   'favourite_count': 0,
#   'retweet_count': 25,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 43, 4)},
#  {'text': 'RT @andrewbostom: UK Medicines &amp; Healthcare products Regulatory Agency has received 2,734 reports of period problems linked to the AstraZen…',
#   'favourite_count': 0,
#   'retweet_count': 45,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 42, 31)},
#  {'text': 'RT @MFTnhs: ‼️ We have walk-in vaccine slots free 𝗧𝗢𝗗𝗔𝗬 for over 18s. ‼️\n\nℹ️ Head to the @MFT_MRI walk-in from 9am-4pm Saturday and Sunday.…',
#   'favourite_count': 0,
#   'retweet_count': 28,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 38, 18)},
#  {'text': 'RT @thewire_in: PHE said that the Pfizer/Biontech COVID-19 vaccine was 96% effective against hospitalisation from the delta variant after t…',
#   'favourite_count': 0,
#   'retweet_count': 18,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 38, 14)},
#  {'text': 'RT @little_b_o_y: Official data, obtained by the\xa0Sunday Times, show that the Medicines &amp; Healthcare products Regulatory Agency (MHRA) recei…',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 37, 39)},
#  {'text': 'RT @PollyWi92611992: #insiders - on vaccine rollout &amp; hesitation around #AstraZeneca.\n Simple answer - incompetent #Morrison says “go for i…',
#   'favourite_count': 0,
#   'retweet_count': 33,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 36, 33)},
#  {'text': '@jamestavendale son just got his  💉 @OfficialTmufc. No queues. No appointment needed. @AstraZeneca &amp; @pfizer. Over 18s. Why not get your son or daughter to go? Open until 8pm. https://t.co/mR8SinYkWK',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 33, 41)},
#  {'text': 'Hmm they REALLY won\'t want you to read this will they "they had been aware of the study, which showed that both the AstraZeneca and Pfizer vaccines were more effective at preventing hospitalisation with the variant than they were against previous strains." https://t.co/mOs6rbl8qy',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 33, 1)},
#  {'text': 'RT @DurhamHealth: Residents who received a first dose of AstraZeneca vaccine are eligible to schedule their second dose appointment for Pfi…',
#   'favourite_count': 0,
#   'retweet_count': 11,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 32, 3)},
#  {'text': 'RT @DurhamHealth: Residents who received a first dose of AstraZeneca vaccine are eligible to schedule their second dose appointment for Pfi…',
#   'favourite_count': 0,
#   'retweet_count': 11,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 31, 14)},
#  {'text': 'RT @eatatjoe2: This is a story that received very little exposure in OZ media. I wonder why? Sounds totally relevant to discussions about A…',
#   'favourite_count': 0,
#   'retweet_count': 68,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 29, 55)},
#  {'text': "RT @Siobhain_Mc: PLEASE SPREAD THE WORD!\n\n8 hours left at Morden's pop up vaccine hub: @OfficialTmufc, Bishopford Road, SM4 6BF\n\nNo queue!…",
#   'favourite_count': 0,
#   'retweet_count': 47,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 29, 42)},
#  {'text': 'RT @CraigKellyMP: What an incompetent clown show 🤡🤡🤡\n\nMore than 800,000 thousands have been injected with a novel experimental genetic agen…',
#   'favourite_count': 0,
#   'retweet_count': 297,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 29, 35)},
#  {'text': 'RT @TheRustler83: 3,752 people have died in Scotland, within 28 days of a vaxxine 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f💉....\n\n1,289 deaths after #Pfizer\n2,461 deaths aft…',
#   'favourite_count': 0,
#   'retweet_count': 1307,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 28, 33)},
#  {'text': 'RT @GabbiBrondani: A fair amount of countries who are re-opening for travel are doing so based on travelers “being vaccinated”. \n\nDubai ann…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 28, 22)},
#  {'text': 'RT @bujibabiera: Making people fall in line for 8 to 12 hours just to get a vaccine—regardless if it’s Sinovac, AstraZeneca, Sputnik or Pfi…',
#   'favourite_count': 0,
#   'retweet_count': 481,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 28, 12)},
#  {'text': 'RT @MFTnhs: ‼️ We have walk-in vaccine slots free 𝗧𝗢𝗗𝗔𝗬 for over 18s. ‼️\n\nℹ️ Head to the @MFT_MRI walk-in from 9am-4pm Saturday and Sunday.…',
#   'favourite_count': 0,
#   'retweet_count': 28,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 27, 19)},
#  {'text': 'RT @NewsBFM: South Korea has decided to give the Pfizer vaccine as a second dose, to 760,000 of its residents which received AstraZeneca fo…',
#   'favourite_count': 0,
#   'retweet_count': 2695,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 26, 17)},
#  {'text': '@LindaDickson58 @ab_vax It’s the clinical evidence for AstraZeneca; 90 days for second dose of the AstraZeneca vaccine, maximizes it’s effect, (this does not include getting an mRNA Pfizer or Moderna as a second dose).  There is no such evidence for other vaccines, so get all other vaccines at 28 days!',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 26, 11)},
#  {'text': 'Pfizer jab deadlier than AstraZeneca across Europe – leaked study https://t.co/nopinVOisX via @YouTube so, pros and cons and fake news and politics',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 25, 57)},
#  {'text': "@sandidakar It's when Pfizer is ring fenced for old people. Astrazeneca is deported across Africa. J&amp;J is put in prison then sent to the rubbish tip. Sputnik is refused entry visa.",
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 25, 40)},
#  {'text': 'RT @jburnmurdoch: Here’s the key table from @PHE_uk new report on vaccine efficacy against hospitalisation with Delta variant:\n\nAfter 1 dos…',
#   'favourite_count': 0,
#   'retweet_count': 2166,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 25, 11)},
#  {'text': 'RT @Saints_Dragons: This was an absolutely appalling decision by Morrison. They refused Pfizer offer of 40 million doses claiming AstraZene…',
#   'favourite_count': 0,
#   'retweet_count': 231,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 24, 48)},
#  {'text': '@ChinasCanada @JamesJa76530712 @SkyNews @pfizer @moderna_tx @AstraZeneca So what, it has zero fecks to do with you what someone else decides to do to there own body you pr1ck.',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 24, 34)},
#  {'text': 'RT @JohnRHewson: For the record, how many of our political leaders had Pfizer rather than AstraZeneca?',
#   'favourite_count': 0,
#   'retweet_count': 890,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 24, 19)},
#  {'text': "RT @Siobhain_Mc: PLEASE SPREAD THE WORD!\n\n8 hours left at Morden's pop up vaccine hub: @OfficialTmufc, Bishopford Road, SM4 6BF\n\nNo queue!…",
#   'favourite_count': 0,
#   'retweet_count': 47,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 24, 10)},
#  {'text': 'RT @DurhamHealth: Residents who received a first dose of AstraZeneca vaccine are eligible to schedule their second dose appointment for Pfi…',
#   'favourite_count': 0,
#   'retweet_count': 11,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 24, 7)},
#  {'text': 'RT @andrewbostom: UK Medicines &amp; Healthcare products Regulatory Agency has received 2,734 reports of period problems linked to the AstraZen…',
#   'favourite_count': 0,
#   'retweet_count': 45,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 23, 48)},
#  {'text': '@JohnRHewson My post on 12/05/21 -  ‘As an older Australian, why should I settle for the AstraZeneca vaccine (60 to 70%)when Pfizer (94%)was provided to Mr Morrison? He is over 50, not a frontline worker or vulnerable!’',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 6, 20, 13, 23, 47)},
#  ...]

# %% [markdown]
# Finally, we convert the `output` list to a `pandas DataFrame` and we store results.

# %%
df = pd.DataFrame(output)

# %%
df.to_csv('output2.csv', mode='a', header = False, index = False )
#df.to_csv('output.csv')

# %%
df.shape
# Out:
# (6510, 4)

# %%
df.head(10)
# Out:
#                                                 text  favourite_count  \
# 0  @breakfasttv I received the Astrazeneca vaccin...                0
# 1  #Pfizer\n#AstraZeneca\n#Moderna\n#JohnsonAndJo...                3
# 2  RT @TimWattsMP: Can you believe this?\n\nThe M...                0
# 3  RT @DrEricDing: 5) One dose of the vaccine is ...                0
# 4  RT @DrEricDing: 5) One dose of the vaccine is ...                0
# 5  RT @DrEricDing: 13) Vaccine effectiveness agai...                0
# 6  RT @james00000001: WHO TO BELIEVE?!\nSQott or ...                0
# 7  RT @ADHDadultlife: Has anyone in the UK had a ...                0
# 8  RT @TimWattsMP: Can you believe this?\n\nThe M...                0
# 9  Not close to what is really happening with the...                0
#
#    retweet_count          created_at
# 0              0 2021-06-20 23:59:37
# 1              5 2021-06-20 23:59:33
# 2            212 2021-06-20 23:58:46
# 3            270 2021-06-20 23:57:54
# 4            270 2021-06-20 23:56:29
# 5             94 2021-06-20 23:54:35
# 6             32 2021-06-20 23:54:18
# 7              1 2021-06-20 23:53:18
# 8            212 2021-06-20 23:51:49
# 9              0 2021-06-20 23:51:45

# %%
df2 = pd.read_csv('output2.csv', names=['text',	'favourite_count',	'retweet_count','created_at'])
df2.head(5)
# Out:
#                                                 text  favourite_count  \
# 0  @breakfasttv I received the Astrazeneca vaccin...                0
# 1  #Pfizer\n#AstraZeneca\n#Moderna\n#JohnsonAndJo...                3
# 2  RT @TimWattsMP: Can you believe this?\n\nThe M...                0
# 3  RT @DrEricDing: 5) One dose of the vaccine is ...                0
# 4  RT @DrEricDing: 5) One dose of the vaccine is ...                0
#
#    retweet_count           created_at
# 0              0  2021-06-20 23:59:37
# 1              5  2021-06-20 23:59:33
# 2            212  2021-06-20 23:58:46
# 3            270  2021-06-20 23:57:54
# 4            270  2021-06-20 23:56:29

# %%
#df = pd.DataFrame(output)
df.to_csv('output3.csv', mode='a', header=True, index = False)

# %%
df3 = pd.read_csv('output3.csv')
df3.head(5)
# Out:
#                                                 text  favourite_count  \
# 0  @breakfasttv I received the Astrazeneca vaccin...                0
# 1  #Pfizer\n#AstraZeneca\n#Moderna\n#JohnsonAndJo...                3
# 2  RT @TimWattsMP: Can you believe this?\n\nThe M...                0
# 3  RT @DrEricDing: 5) One dose of the vaccine is ...                0
# 4  RT @DrEricDing: 5) One dose of the vaccine is ...                0
#
#    retweet_count           created_at
# 0              0  2021-06-20 23:59:37
# 1              5  2021-06-20 23:59:33
# 2            212  2021-06-20 23:58:46
# 3            270  2021-06-20 23:57:54
# 4            270  2021-06-20 23:56:29

# %%
df3.shape
# Out:
# (6510, 4)

# %%
#nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

# %%
df3['rating'] = df3['text'].apply(sid.polarity_scores)

# %%
df3
# Out:
#                                                    text  favourite_count  \
# 0     @breakfasttv I received the Astrazeneca vaccin...                0
# 1     #Pfizer\n#AstraZeneca\n#Moderna\n#JohnsonAndJo...                3
# 2     RT @TimWattsMP: Can you believe this?\n\nThe M...                0
# 3     RT @DrEricDing: 5) One dose of the vaccine is ...                0
# 4     RT @DrEricDing: 5) One dose of the vaccine is ...                0
# ...                                                 ...              ...
# 6505  @Fab485617452 @JohnRHewson I'm 73 and my wife ...                6
# 6506  RT @kyle_minogue: @bjornradstrom Pfizer - 12-1...                0
# 6507  RT @JohnRHewson: For the record, how many of o...                0
# 6508  RT @JohnRHewson: For the record, how many of o...                0
# 6509  RT @DrEricDing: 3) “After years of reading res...                0
#
#       retweet_count           created_at  \
# 0                 0  2021-06-20 23:59:37
# 1                 5  2021-06-20 23:59:33
# 2               212  2021-06-20 23:58:46
# 3               270  2021-06-20 23:57:54
# 4               270  2021-06-20 23:56:29
# ...             ...                  ...
# 6505              0  2021-06-19 00:02:33
# 6506              2  2021-06-19 00:02:21
# 6507            890  2021-06-19 00:01:32
# 6508            890  2021-06-19 00:00:27
# 6509             55  2021-06-19 00:00:08
#
#                                                  rating
# 0     {'neg': 0.049, 'neu': 0.752, 'pos': 0.199, 'co...
# 1     {'neg': 0.0, 'neu': 0.603, 'pos': 0.397, 'comp...
# 2     {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'comp...
# 3     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                 ...
# 6505  {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'comp...
# 6506  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6507  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6508  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6509  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [6510 rows x 5 columns]

# %%
df3['negative_nltk'] = df3['rating'].apply(lambda x : x['neg'])
df3['positive_nltk'] = df3['rating'].apply(lambda x : x['pos'])
df3['neutral_nltk'] = df3['rating'].apply(lambda x : x['neu'])
df3['ncompound_nltk'] = df3['rating'].apply(lambda x : x['compound'])

df3 = df3.drop('rating', axis=1)
df3
# Out:
#                                                    text  favourite_count  \
# 0     @breakfasttv I received the Astrazeneca vaccin...                0
# 1     #Pfizer\n#AstraZeneca\n#Moderna\n#JohnsonAndJo...                3
# 2     RT @TimWattsMP: Can you believe this?\n\nThe M...                0
# 3     RT @DrEricDing: 5) One dose of the vaccine is ...                0
# 4     RT @DrEricDing: 5) One dose of the vaccine is ...                0
# ...                                                 ...              ...
# 6505  @Fab485617452 @JohnRHewson I'm 73 and my wife ...                6
# 6506  RT @kyle_minogue: @bjornradstrom Pfizer - 12-1...                0
# 6507  RT @JohnRHewson: For the record, how many of o...                0
# 6508  RT @JohnRHewson: For the record, how many of o...                0
# 6509  RT @DrEricDing: 3) “After years of reading res...                0
#
#       retweet_count           created_at  negative_nltk  positive_nltk  \
# 0                 0  2021-06-20 23:59:37          0.049          0.199
# 1                 5  2021-06-20 23:59:33          0.000          0.397
# 2               212  2021-06-20 23:58:46          0.124          0.000
# 3               270  2021-06-20 23:57:54          0.000          0.000
# 4               270  2021-06-20 23:56:29          0.000          0.000
# ...             ...                  ...            ...            ...
# 6505              0  2021-06-19 00:02:33          0.000          0.073
# 6506              2  2021-06-19 00:02:21          0.000          0.000
# 6507            890  2021-06-19 00:01:32          0.000          0.000
# 6508            890  2021-06-19 00:00:27          0.000          0.000
# 6509             55  2021-06-19 00:00:08          0.000          0.000
#
#       neutral_nltk  ncompound_nltk
# 0            0.752          0.7793
# 1            0.603          0.7639
# 2            0.876         -0.4019
# 3            1.000          0.0000
# 4            1.000          0.0000
# ...            ...             ...
# 6505         0.927          0.3818
# 6506         1.000          0.0000
# 6507         1.000          0.0000
# 6508         1.000          0.0000
# 6509         1.000          0.0000
#
# [6510 rows x 8 columns]
